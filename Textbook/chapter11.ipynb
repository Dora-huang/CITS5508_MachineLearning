# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
from numba import cuda
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-2a3adfcaa80e> in <module>
# ----> 1 from numba import cuda
#
# ModuleNotFoundError: No module named 'numba'

# %%
len(tf.config.experimental.list_physical_devices("GPU"))
# Out:
# 0

# %%
from tensorflow.python.client import device_lib

# %%
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9722801938314575156
# ]

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# Using TensorFlow backend.
# []

# %%
import keras
config = tf.ConfigProto(device_count = {'GPU': 1 , 'CPU': 56} ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e98cb5273204> in <module>
#       1 import keras
# ----> 2 config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 56} )
#       3 sess = tf.Session(config=config)
#       4 keras.backend.set_session(sess)
#
# AttributeError: module 'tensorflow' has no attribute 'ConfigProto'

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0
X_valid, X_train = X_train_full[:5000], X_train_full[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %%
def split_dataset(X, y):
    y_5_or_6 = (y == 5) | (y == 6) # sandals or shirts
    y_A = y[~y_5_or_6]
    y_A[y_A > 6] -= 2 # class indices 7, 8, 9 should be moved to 5, 6, 7
    y_B = (y[y_5_or_6] == 6).astype(np.float32) # binary classification task: is it a shirt (class 6)?
    return ((X[~y_5_or_6], y_A),
            (X[y_5_or_6], y_B))

(X_train_A, y_train_A), (X_train_B, y_train_B) = split_dataset(X_train, y_train)
(X_valid_A, y_valid_A), (X_valid_B, y_valid_B) = split_dataset(X_valid, y_valid)
(X_test_A, y_test_A), (X_test_B, y_test_B) = split_dataset(X_test, y_test)
X_train_B = X_train_B[:200]
y_train_B = y_train_B[:200]

# %%
model_A = keras.models.Sequential()
model_A.add(keras.layers.Flatten(input_shape=[28, 28]))
for n_hidden in (300, 100, 50, 50, 50):
    model_A.add(keras.layers.Dense(n_hidden, activation="selu"))
model_A.add(keras.layers.Dense(8, activation="softmax"))

# %%
model_A.compile(loss="sparse_categorical_crossentropy",
                optimizer=keras.optimizers.SGD(lr=1e-3),
                metrics=["accuracy"])

# %%
history = model_A.fit(X_train_A, y_train_A, epochs=20,
                    validation_data=(X_valid_A, y_valid_A))
# Out:
# Train on 43986 samples, validate on 4014 samples
# Epoch 1/20
# 43986/43986 [==============================] - 11s 252us/sample - loss: 0.5909 - accuracy: 0.8100 - val_loss: 0.3772 - val_accuracy: 0.8705
# Epoch 2/20
# 43986/43986 [==============================] - 8s 186us/sample - loss: 0.3520 - accuracy: 0.8792 - val_loss: 0.3396 - val_accuracy: 0.8769
# Epoch 3/20
# 43986/43986 [==============================] - 8s 177us/sample - loss: 0.3167 - accuracy: 0.8892 - val_loss: 0.3018 - val_accuracy: 0.8959
# Epoch 4/20
# 26784/43986 [=================>............] - ETA: 2s - loss: 0.3002 - accuracy: 0.8967
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-0e403b5eb788> in <module>
#       1 history = model_A.fit(X_train_A, y_train_A, epochs=20,
# ----> 2                     validation_data=(X_valid_A, y_valid_A))
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# D:\Anaconda\envs\CITS5508\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
model_A.save("my_model_A.h5")

# %%
model_A.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 408
# =================================================================
# Total params: 276,158
# Trainable params: 276,158
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_B = keras.models.Sequential()
model_B.add(keras.layers.Flatten(input_shape=[28, 28]))
for n_hidden in (300, 100, 50, 50, 50):
    model_B.add(keras.layers.Dense(n_hidden, activation="selu"))
model_B.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
model_B.compile(loss="binary_crossentropy",
                optimizer=keras.optimizers.SGD(lr=1e-3),
                metrics=["accuracy"])

# %%
history = model_B.fit(X_train_B, y_train_B, epochs=20,
                      validation_data=(X_valid_B, y_valid_B))
# Out:
# Train on 200 samples, validate on 986 samples
# Epoch 1/20
# 200/200 [==============================] - 3s 13ms/sample - loss: 0.9545 - accuracy: 0.4600 - val_loss: 0.6655 - val_accuracy: 0.5385
# Epoch 2/20
# 200/200 [==============================] - 0s 742us/sample - loss: 0.5899 - accuracy: 0.6900 - val_loss: 0.4785 - val_accuracy: 0.8519
# Epoch 3/20
# 200/200 [==============================] - 0s 810us/sample - loss: 0.4512 - accuracy: 0.8800 - val_loss: 0.4098 - val_accuracy: 0.8945
# Epoch 4/20
# 200/200 [==============================] - 0s 751us/sample - loss: 0.3871 - accuracy: 0.9100 - val_loss: 0.3666 - val_accuracy: 0.9128
# Epoch 5/20
# 200/200 [==============================] - 0s 766us/sample - loss: 0.3438 - accuracy: 0.9250 - val_loss: 0.3315 - val_accuracy: 0.9300
# Epoch 6/20
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.3095 - accuracy: 0.9300 - val_loss: 0.3034 - val_accuracy: 0.9402
# Epoch 7/20
# 200/200 [==============================] - 0s 2ms/sample - loss: 0.2810 - accuracy: 0.9400 - val_loss: 0.2808 - val_accuracy: 0.9432
# Epoch 8/20
# 200/200 [==============================] - 0s 2ms/sample - loss: 0.2580 - accuracy: 0.9500 - val_loss: 0.2618 - val_accuracy: 0.9462
# Epoch 9/20
# 200/200 [==============================] - 0s 871us/sample - loss: 0.2372 - accuracy: 0.9600 - val_loss: 0.2447 - val_accuracy: 0.9513
# Epoch 10/20
# 200/200 [==============================] - 0s 839us/sample - loss: 0.2196 - accuracy: 0.9650 - val_loss: 0.2316 - val_accuracy: 0.9513
# Epoch 11/20
# 200/200 [==============================] - 0s 853us/sample - loss: 0.2048 - accuracy: 0.9650 - val_loss: 0.2182 - val_accuracy: 0.9533
# Epoch 12/20
# 200/200 [==============================] - 0s 859us/sample - loss: 0.1915 - accuracy: 0.9650 - val_loss: 0.2071 - val_accuracy: 0.9564
# Epoch 13/20
# 200/200 [==============================] - 0s 920us/sample - loss: 0.1791 - accuracy: 0.9650 - val_loss: 0.1959 - val_accuracy: 0.9594
# Epoch 14/20
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.1681 - accuracy: 0.9700 - val_loss: 0.1864 - val_accuracy: 0.9604
# Epoch 15/20
# 200/200 [==============================] - 0s 872us/sample - loss: 0.1579 - accuracy: 0.9850 - val_loss: 0.1778 - val_accuracy: 0.9625
# Epoch 16/20
# 200/200 [==============================] - 0s 883us/sample - loss: 0.1491 - accuracy: 0.9850 - val_loss: 0.1695 - val_accuracy: 0.9675
# Epoch 17/20
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.1411 - accuracy: 0.9900 - val_loss: 0.1626 - val_accuracy: 0.9686
# Epoch 18/20
# 200/200 [==============================] - 0s 932us/sample - loss: 0.1339 - accuracy: 0.9900 - val_loss: 0.1570 - val_accuracy: 0.9686
# Epoch 19/20
# 200/200 [==============================] - 0s 899us/sample - loss: 0.1277 - accuracy: 0.9900 - val_loss: 0.1522 - val_accuracy: 0.9696
# Epoch 20/20
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.1217 - accuracy: 0.9900 - val_loss: 0.1471 - val_accuracy: 0.9696

# %%
model_A = keras.models.load_model("my_model_A.h5")
model_B_on_A = keras.models.Sequential(model_A.layers[:-1])
model_B_on_A.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
model_A.layers[:-1]
# Out:
# [<tensorflow.python.keras.layers.core.Flatten at 0x2573664e948>,
#  <tensorflow.python.keras.layers.core.Dense at 0x25736832c48>,
#  <tensorflow.python.keras.layers.core.Dense at 0x257373289c8>,
#  <tensorflow.python.keras.layers.core.Dense at 0x2573664e548>,
#  <tensorflow.python.keras.layers.core.Dense at 0x2573663f0c8>,
#  <tensorflow.python.keras.layers.core.Dense at 0x25737324948>]

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False

model_B_on_A.compile(loss="binary_crossentropy",
                     optimizer=keras.optimizers.SGD(lr=1e-3),
                     metrics=["accuracy"])

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True

# %%
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=4,
                           validation_data=(X_valid_B, y_valid_B))

for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True

model_B_on_A.compile(loss="binary_crossentropy",
                     optimizer=keras.optimizers.SGD(lr=1e-3),
                     metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=16,
                           validation_data=(X_valid_B, y_valid_B))
# Out:
# Train on 200 samples, validate on 986 samples
# Epoch 1/4
# 200/200 [==============================] - 2s 8ms/sample - loss: 0.5787 - accuracy: 0.6550 - val_loss: 0.5796 - val_accuracy: 0.6450
# Epoch 2/4
# 200/200 [==============================] - 0s 716us/sample - loss: 0.5407 - accuracy: 0.7050 - val_loss: 0.5453 - val_accuracy: 0.6805
# Epoch 3/4
# 200/200 [==============================] - 0s 853us/sample - loss: 0.5069 - accuracy: 0.7150 - val_loss: 0.5149 - val_accuracy: 0.7150
# Epoch 4/4
# 200/200 [==============================] - 0s 788us/sample - loss: 0.4769 - accuracy: 0.7450 - val_loss: 0.4857 - val_accuracy: 0.7312
# Train on 200 samples, validate on 986 samples
# Epoch 1/16
# 200/200 [==============================] - 2s 12ms/sample - loss: 0.3952 - accuracy: 0.8250 - val_loss: 0.3375 - val_accuracy: 0.8722
# Epoch 2/16
# 200/200 [==============================] - 0s 792us/sample - loss: 0.2744 - accuracy: 0.9300 - val_loss: 0.2607 - val_accuracy: 0.9270
# Epoch 3/16
# 200/200 [==============================] - 0s 908us/sample - loss: 0.2105 - accuracy: 0.9650 - val_loss: 0.2149 - val_accuracy: 0.9523
# Epoch 4/16
# 200/200 [==============================] - 0s 760us/sample - loss: 0.1709 - accuracy: 0.9750 - val_loss: 0.1804 - val_accuracy: 0.9655
# Epoch 5/16
# 200/200 [==============================] - 0s 861us/sample - loss: 0.1413 - accuracy: 0.9800 - val_loss: 0.1574 - val_accuracy: 0.9757
# Epoch 6/16
# 200/200 [==============================] - 0s 868us/sample - loss: 0.1213 - accuracy: 0.9900 - val_loss: 0.1395 - val_accuracy: 0.9807
# Epoch 7/16
# 200/200 [==============================] - 0s 792us/sample - loss: 0.1057 - accuracy: 0.9950 - val_loss: 0.1261 - val_accuracy: 0.9828
# Epoch 8/16
# 200/200 [==============================] - 0s 886us/sample - loss: 0.0936 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9848
# Epoch 9/16
# 200/200 [==============================] - 0s 781us/sample - loss: 0.0841 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 0.9858
# Epoch 10/16
# 200/200 [==============================] - 0s 823us/sample - loss: 0.0768 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9858
# Epoch 11/16
# 200/200 [==============================] - 0s 792us/sample - loss: 0.0708 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9899
# Epoch 12/16
# 200/200 [==============================] - 0s 836us/sample - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.0898 - val_accuracy: 0.9899
# Epoch 13/16
# 200/200 [==============================] - 0s 866us/sample - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9899
# Epoch 14/16
# 200/200 [==============================] - 0s 791us/sample - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9899
# Epoch 15/16
# 200/200 [==============================] - 0s 767us/sample - loss: 0.0532 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9899
# Epoch 16/16
# 200/200 [==============================] - 0s 769us/sample - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9899

# %%
model_B.evaluate(X_test_B, y_test_B)
# Out:
# 2000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.1444666247367859, 0.9695]

# %%
model_B_on_A.evaluate(X_test_B, y_test_B)
# Out:
# 2000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.06902516719698906, 0.993]
